# %% [markdown]
# <a href="https://colab.research.google.com/github/shifanabila3434-max/Shifa-Nabila/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
from nltk.tokenize import word_tokenize
from keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, concatenate
from tensorflow.keras.layers import Embedding
from keras.utils import plot_model

# %%
df = pd.read_csv('/content/all_agree.csv')
df.head()
# Out:
#                                                title          label  \
# 0  Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...  non-clickbait
# 1  Malaysia Sudutkan RI: Isu Kabut Asap hingga In...  non-clickbait
# 2  Viral! Driver Ojol di Bekasi Antar Pesanan Mak...      clickbait
# 3  Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...  non-clickbait
# 4  MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...  non-clickbait
#
#    label_score
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0

# %%
df['label_score'].value_counts()
# Out:
# label_score
# 0    5297
# 1    3316
# Name: count, dtype: int64

# %%
def find_punc(x, punc):
  count = 0
  for char in x:
      if char == punc:
          count += 1
  return count

# %%
df['ccount'] = df['title'].apply(lambda x: find_punc(x, ','))
df['klctop_count'] = df['title'].apply(lambda x: find_punc(x, '.'))
df['excl_mark_count'] = df['title'].apply(lambda x: find_punc(x, '!'))
df['que_mark_count'] = df['title'].apply(lambda x: find_punc(x, '?'))
df['col_count'] = df['title'].apply(lambda x: find_punc(x, ':'))
df['semi_col_count'] = df['title'].apply(lambda x: find_punc(x, ';'))
df['sq_col_count'] = df['title'].apply(lambda x: find_punc(x, "'"))

# %%
df.shape
# Out:
# (8613, 10)

# %%
def find_uppercase(x):
    count = 0
    for char in x:
        if char.isupper() :
            count +=1
    return count

def find_lowercase(x):
    count = 0
    for char in x:
        if char.islower() :
            count += 1
    return count

def find_number(x):
    return len(re.findall('[0-9]', x))

# %%
df['uppercase_count'] = df['title'].apply(find_uppercase)
df['lowercase_count'] = df['title'].apply(find_lowercase)
df['number_count'] = df['title'].apply(find_number)

# %%
df.shape
# Out:
# (8613, 13)

# %%
import nltk
nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
def clean(text):
    # Lowering letters
    text = text.lower()
    # Removing punctuations
    text = re.sub('[, .!?:;  \']', '', text)
    # Tokenization
    word_tokens = word_tokenize(text)
    # Joining words
    text = (' '.join(word_tokens))
    return text

# %%
df['cleaned_title'] = df['title'].apply(clean)

# %%
df[['title', 'cleaned_title']]
# Out:
#                                                   title  \
# 0     Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...
# 1     Malaysia Sudutkan RI: Isu Kabut Asap hingga In...
# 2     Viral! Driver Ojol di Bekasi Antar Pesanan Mak...
# 3     Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...
# 4     MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...
# ...                                                 ...
# 8608  Twice Rilis Teaser MV 'Feel Special' Jelang Co...
# 8609   Asap Karhutla Riau Mulai Merambah Ke Nias, BM...
# 8610  Tolak RUU Pertanahan, Ribuan Petani Siap Gelar...
# 8611  Ada Niat Tambah Momongan Tanpa Ikut Program Ha...
# 8612   TXT Akan Segera Comeback, Soobin Akui Gatal I...
#
#                                           cleaned_title
# 0     masukradarpilwalkotmedanmenantujokowibertemudp...
# 1        malaysiasudutkanriisukabutasaphinggainvasibabi
# 2     viraldriverojoldibekasiantarpesananmakananpaka...
# 3     kemensossalurkanrp73mbagikorbankerusuhansosial...
# 4          mpramandemenuud1945takakanmelebarkemana-mana
# ...                                                 ...
# 8608  twicerilisteasermvfeelspecialjelangcomebackkon...
# 8609  asapkarhutlariaumulaimerambahkeniasbmkgimbauwa...
# 8610  tolakruupertanahanribuanpetanisiapgelaraksidii...
# 8611  adaniattambahmomongantanpaikutprogramhamilfedi...
# 8612  txtakansegeracomebacksoobinakuigatalinginpamer...
#
# [8613 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['title', 'label', 'label_score', 'ccount', 'klctop_count',
#        'excl_mark_count', 'que_mark_count', 'col_count', 'semi_col_count',
#        'sq_col_count', 'uppercase_count', 'lowercase_count', 'number_count',
#        'cleaned_title'],
#       dtype='object')

# %%
X = df.iloc[ :, 3: ]
y = df. iloc[ :, 2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.2,
random_state=77)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6890, 11)
# (1723, 11)

# %%
X_train_title = X_train['cleaned_title' ]
X_test_title = X_test['cleaned_title']

X_train_punc = X_train.drop('cleaned_title', axis=1)
X_test_punc = X_test.drop('cleaned_title', axis=1)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train['cleaned_title'])

X_train_title = tokenizer.texts_to_sequences(X_train['cleaned_title'])
X_test_title = tokenizer.texts_to_sequences(X_test['cleaned_title'])

# %%
tokenizer.word_index
# Out:
# {"''": 1,
#  'gara': 2,
#  'timnasu': 3,
#  'garaini': 4,
#  '0': 5,
#  '1': 6,
#  'undang': 7,
#  'timnasindonesiau': 8,
#  '16': 9,
#  'surabayamenggugat': 10,
#  '2020': 11,
#  '3': 12,
#  'cukainaik23': 13,
#  'hati': 14,
#  'topikpagi': 15,
#  'pdi': 16,
#  'siap': 17,
#  'hutke': 18,
#  'diawasidihongkongaktivisjoshuawongterbangkeberlin': 19,
#  'anak': 20,
#  'maruf': 21,
#  'x': 22,
#  'hatta': 23,
#  'zodiakmingguan16': 24,
#  '2019': 25,
#  '162020': 26,
#  'pemerintah': 27,
#  'leeminjung': 28,
#  'habisan': 29,
#  'luka': 30,
#  'tahundepanadakebijakancukaibaruapasajaisinya': 31,
#  'kejang': 32,
#  'garahalini': 33,
#  'junu': 34,
#  'cerai': 35,
#  'demokratsiapbantupemerintahanjokowi': 36,
#  'emak': 37,
#  'timorleste': 38,
#  'jadwalbolaakhirpekanligainggrisligaspanyolligaitalia': 39,
#  'gram': 40,
#  '9': 41,
#  '11': 42,
#  'ksditunda': 43,
#  'videodetik': 44,
#  'aksi': 45,
#  'off': 46,
#  'undangkpk': 47,
#  'pembangunansekolahindonesia': 48,
#  'madiun': 49,
#  'blak': 50,
#  'usd': 51,
#  'coba': 52,
#  'kis': 53,
#  'kemkominfososialisasikanmanfaatbantuansosialkepadakpmbpnt': 54,
#  'pkh': 55,
#  '20': 56,
#  'marcus': 57,
#  'indonesiamampupenuhiproteinhewanidalamnegeri': 58,
#  'empatmahasiswaindonesiadiaustraliapernahbunuhdiriapayangbisadicegah': 59,
#  'trick': 60,
#  'indonesiadermawan': 61,
#  '7k': 62,
#  'asean': 63,
#  'previewtimnasu': 64,
#  'fakta': 65,
#  'rizki': 66,
#  '2023': 67,
#  'besaran': 68,
#  'industriasuransioptimistiskembangkanpasardenganjkn': 69,
#  'faktalengkapproducex101yangperlukamutahu': 70,
#  'jadwalsiaranlangsungtimnasindonesiavsthailanddikualifikasipialadunia2022': 71,
#  'manfarfromhome': 72,
#  'jadwalmuvsleicestercitydiligainggrissiaranlangsungtelevisi': 73,
#  'peringatitahunbaruislambanyuwangikembaligelarfestivalmuharam': 74,
#  'viralemak': 75,
#  'warni': 76,
#  '2': 77,
#  'sudahdikafanibangkitlagiternyatapura': 78,
#  'puramatikarenabanyakutang': 79,
#  'ketemumarshandaraffiahmaddibuatsalahtingkah': 80,
#  'lagipestaganjadigrebekpolisipemudainingompoldicelana': 81,
#  'solskjaerdanieljamesmasihbisalebihbaguslagi': 82,
#  'gantikanjohnnyplatetaufikbasariditunjukjadiketuafraksinasdemmpr': 83,
#  'asapindonesiamulaiganggurodaekonomimalaysia': 84,
#  'ojekonlinetolakgabungdemoburuhkarenaalasanini': 85,
#  'ambondiguncangsejumlahgempadalamsemalam': 86,
#  'rayakanulangtahundufanajak1500anakyatimmainbersama': 87,
#  'dapatjatahwamenprojonggakjadibubardanmalahpujiprabowo': 88,
#  'pembalapaustraliaterjatuhtimindonesiajuaraietapeiitourdesiak': 89,
#  'maindikandangborneofcmaduraunitedpunyatargetini': 90,
#  'kabutasapmenebalpenerbanganlokaldilinggariaudibatalkan': 91,
#  'giselbantahtularidugemliaraurelcuekminum': 92,
#  'minumpamerkakinyilangseksi': 93,
#  'munculdigeekbenchgooglepixel4xl5gpunyaram8gbdansd855': 94,
#  'pernahdiajaktidurbarengdivilahinggahamilbibiakhirnyapolisikanpakkades': 95,
#  'pkbtidaksiapkanpenggantiimamnahrawi': 96,
#  'proyektollayangjakarta': 97,
#  'cikampekiitargetrampungakhirseptember': 98,
#  'kyaicholilprogrampetanimilenialhidupkanmentalsantri': 99,
#  'pesertabpjskesehatandiperkirakanbanyakyangpindahkekelaslebihrendah': 100,
#  'twicebeberrahasiatetapsoliddanberikabarsoalkondisimina': 101,
#  'mengenalnovianapengamencantikwisudawanterbaikdiuniversitasairlangga': 102,
#  'festivalgarisimaginerdigelarakhirpekanini': 103,
#  'kuasahukummintapemanggilanketuaumumfpisebagaisaksikasusmakardijadwalulang': 104,
#  'nagitaslavinaketakutannaiksepedamalahbikinfansgemas': 105,
#  'revisiuukpkdinilaiuntungkanmafiatambanginipenjelasannya': 106,
#  'ketuamrpbantahkepulanganmahasiswapapuakarenamaklumatyangdikeluarkan': 107,
#  'beginicaraadipatidolkendalamiperansebagaikasino': 108,
#  'fujifilmluncurkankamerax': 109,
#  'a7untukpemula': 110,
#  'usaidilantikanggotadprtermudahillarylasutlangsungserangrkuhp': 111,
#  '16ikutikualifikasipialaafcu': 112,
#  '16inihargatiketnya': 113,
#  'statustersangkaveronicakomandisoalpolriadapraperadilan': 114,
#  'ditangkapgegarakasusnarkobaputrisribintangtegaskantakterkaitpolitik': 115,
#  'presidenjokowimintapengesahanruukuhpditunda': 116,
#  '4alasansakitperutusaiberolahragasalahsatunyadehidrasi': 117,
#  '30065hektarelahanriauterbakar': 118,
#  'truktrontonjadipenyebabkecelakaantolcipularang': 119,
#  'sinopsissinetroncintabutaepisode74': 120,
#  '75tayangsenin8april2019': 121,
#  '8halyangdiperhatikanpriadarimusaatpertamakalibertemu': 122,
#  'agarhatilembuttaksekerasbatulakukan7amalansederhanaini': 123,
#  'siapkandiriuntuknostalgiadifilmthelionking2019': 124,
#  'tibadikantordprdsulselmassapelajardisambutmahasiswa': 125,
#  'terminal2bernamabandarasoettatravelokaapiikecolongan': 126,
#  'utusankhususpresidenakangelarmunastokohantaragama': 127,
#  'capimkpklilisayasetujurevisiuuuntukpenguatan': 128,
#  'setelahmelahirkanbayilaki': 129,
#  'laki10kaliberturut': 130,
#  'turutibuiniakhirnyadikaruniaianakperempuan': 131,
#  'hadapierarobotgeneraliindonesiatawarkanperencanaanpendidikananak': 132,
#  'warganyajadikorbanbupatipuncakmintastopbakutembak': 133,
#  'googleditudingmenakut': 134,
#  'nakutipenggunaiphonedengancelahkeamanan': 135,
#  'soalkembaliberpindahkeyakinaninitanggapanpengacarasteveemmanuel': 136,
#  '5potretkedekatanmayangsaridenganputrisematawayangmiripanakkembar': 137,
#  'kejamsekalihoaxtentangmeninggalnyabjhabibiesudah6kaliterjadisejak2012': 138,
#  'setelahkenaseranganjantungikercasillaskinilatihanlagi': 139,
#  'polisipanggilketumfpipengacaraeggisudjanabilangbegini': 140,
#  'netanyahuklaimiranpunyasitusrahasiaprogramsenjatanuklir': 141,
#  'aniesbaswedandoakanbjhabibiebisakembalisehat': 142,
#  'pakaimejadaripintubekasbawaamazonjadiperusahaanberkelas': 143,
#  'riofebrianberdukasangibumeninggaldunia': 144,
#  'airlanggahartartomintakadergolkardidprkawalkebijakanjokowi': 145,
#  'gagalcokoktersangkakerusuhanpapuainiyangditemukanpolisi': 146,
#  'sinopsissinetroncintasuciepisode299': 147,
#  '300tayangkamis4april2019': 148,
#  'kebakaranhutangunungciremaihanguskan150hektarelahan': 149,
#  'whoopigoldbergkritikdonaldtrumpsoalpengungsibahama': 150,
#  'dampakkabutasappuluhanribuwargaterserangispahinggawargasalatmintahujan': 151,
#  'dprddkimintagubernurwajiblaporjikagantiwalikotaanieskansudahselamaini': 152,
#  'kandidattuanrumahpialaduniau': 153,
#  '20delegasififainspeksistadionmanahansolo': 154,
#  'rossidanmarquezbersiteganglagidigpsanmarino': 155,
#  'pacarmuseringmerasapalingbenarmungkinmerekamasuk5zodiakini': 156,
#  'pengusahaajukannamacalonmenterikejokowiinidaftarnya': 157,
#  'ribuanwargabantulgelarkirabsiwurjelangupacarangurasenceh': 158,
#  'pasalunggasjalan': 159,
#  'jalandiruukuhpadakasuskonkretnyayukbaca': 160,
#  'belumamanolahtkpledakandimakobrimobsrondolditunda': 161,
#  'dugaankorupsikpurp12tdilaporkankekpkbeginirinciannya': 162,
#  'tipsamanberkendarajikakehilanganjarakpandangakibatkabutasap': 163,
#  'shandyauliapamerhasilusghidungmancungsangjabangbayijadisorotan': 164,
#  'gaspoldancyberjecksegeraberoperasidiindonesia': 165,
#  'sinopsisdramastill17episode23yangsejong': 166,
#  'shinhyesunmulaisalingterbuka': 167,
#  'kivlanzenperintahkanpembeliansenjataharusdibelisebelumpemilu': 168,
#  '7caramengetahuianakkesepianperhatikantandanya': 169,
#  'resepcekerayamdimsum': 170,
#  'blackpinkselalukenakankostumkerendigayodaejunmanayangterbaik': 171,
#  'tanggapipermohonanpknovantojaksasinggungsumpahdipengadilan': 172,
#  'massademopenuhijalangatotsubrotodepandprlalinditutup': 173,
#  '7tipsinibakalbantukalianmenentukanukuransepatusaatbelanjaonlinedijaminakurat': 174,
#  'hilangdigoogleplaystorebukalapakkamilakukanpembaharuan': 175,
#  'syahrinipamerkoloremashargaselangitpenyebabcelanareinobolongternodaterbongkar': 176,
#  'polritetapkan175tersangkakarhutla': 177,
#  '5koleksitasmewahlucintalunabikinjiwamiskinnetizenmeronta': 178,
#  'ronta': 179,
#  'berakhirpekandimalioborokunjungiduapameranseniini': 180,
#  'polusiasapsdncilincingpasangalatpenyaringudaradikelas': 181,
#  'polisiancamkeluarkanrednoticeuntukveronicakoman': 182,
#  'jokowiingatkantakadaistilahpengembalianmandatdiuukpk': 183,
#  'kronologilengkappemudadibandungtusukgadispujaankarenacintaditolak': 184,
#  'ini5bankyangtawarkanbungadepositotertinggi': 185,
#  'ganjarpranowolantikpengdakagamasulawesiutara': 186,
#  'stadionmanahanbarusiapdigunakanprosesrenovasisudah99': 187,
#  'rampung': 188,
#  'bnnklaimpenyelundupannarkotikakeindonesiamenurun30': 189,
#  'checkuphasilusgnikitamirzanibersyukurbayinyasehat': 190,
#  'plnserahkanpenyelidikanpenyebabpemadamanlistrikkebareskrim': 191,
#  'dearpenggunaiphonelakukanlangkahiniuntukhindari25ribumata': 192,
#  'matadiponselmu': 193,
#  'pengemudigo': 194,
#  'foodyanggunakansepedabantahmotornyadipakaianaknyakesekolah': 195,
#  'jackmaresmipensiundarialibabagroup': 196,
#  'mertesackeroezilmasihmamputingkatkanperformaarsenal': 197,
#  'memanasmahasiswapenolakuukpkbaru': 198,
#  'rkuhplemparbotol': 199,
#  'dorongpagar': 200,
#  'menkumhampecabutanpasporveronicakomansesuaiaturan': 201,
#  'btpnpenurunanbiratepositifturunkanbebanbunga': 202,
#  'mahasiswatetapdesakjokowiterbitkanperppukpkridaruratkorupsi': 203,
#  'mintadilibatkandalamrevisiuukpkakankirimsuratkedpr': 204,
#  'delonthamrintakperbolehkancalonistrimakanbanyakjelangharipernikahan': 205,
#  'kapalpenghancuramerikatantangcinasoallautcinaselatan': 206,
#  'datapenumpangbocorlionairmengakujadikorban': 207,
#  'hebohterminal2bandarasoettagantinamajaditravelokabeginipenjelasannya': 208,
#  'krisdayantiumbarcincinthanosmewahdipelantikandprsuamicurhatbisnisgulungtikar': 209,
#  'livestreamingvidiocombadaklampungvsperselalamongandishopeeliga12019': 210,
#  'gubernurriaudidesaktetapkanstatusdaruratasap': 211,
#  'fahrimintapenolakuukpkbersikapjantantunjukkankajiannya': 212,
#  'jaksakpkmintamatolakpknovanto': 213,
#  'budiwasesoungkapmoduskejahatanpenyalurberasbpnt': 214,
#  'jelangsambuthariulangtahungtvsiapkanbigmoviesspesialamazing17': 215,
#  'muhammadiyahdiykeluarkanedaranmeresponsseruandemopelajar': 216,
#  'wallstreetmenguattipisjelangkeputusansukubungathefed': 217,
#  'ambisisalimgroupkembangkanindustrigimindonesialewatakggames': 218,
#  'pssiresmibukapendaftarancalonketuaumum': 219,
#  'walikotadepokturutberdukameninggalnyabjhabibie': 220,
#  'suvmewahrolls': 221,
#  'roycecullinankenarecallapayangbermasalah': 222,
#  'kecantikanjangdongyoonjadibahasandilokasithetaleofnokdukimsohyunngakukalahcantik': 223,
#  'lepaskepergianhabibiewargapadatitmpkalibata': 224,
#  '2020hondajazzhybridbelumakanmasukkeindonesia': 225,
#  'sitinurazizahsiapberjuangjadicalonwalikotatangsel': 226,
#  'bubarkandiripesertaaksigejayanmemanggilpungutisampah': 227,
#  'mulanjameelacsditetapkanjadianggotadprinipenjelasangerindra': 228,
#  'jaminankesehatanharusjadiperhatian': 229,
#  'aniespekerjaanpetugasambulanstaksederhanaadapotensikenafitnah': 230,
#  'pasarkosambiakanjadimalpelayananpubliktungguizinkemenpanrb': 231,
#  'massadibandungbentangkanspandukpapuaituindonesia': 232,
#  'massadijalankstubunbubarpersoneltniberjagadislipi': 233,
#  'gaunpengantinmewahsyahrinidigaladinnersempatmunculdifashionshow': 234,
#  'trendingtopicsiswasmkn7medanmintakeadilanpolantasmalahkabur': 235,
#  '70brigifraider13ziarahkemakambupatigaluhciamis': 236,
#  'garethsouthgatekhawatirterimaumpatanrasial': 237,
#  'unggahhasiljepretanreinobaracksyahrinianggundipematangsawah': 238,
#  'chinaopen2019hafiz': 239,
#  'gloriaakuikeunggulanwakilthailand': 240,
#  'khameneiditudingsetujuiseranganterhadapkilangminyaksaudi': 241,
#  'rapatinvestorygentertainmentselesaidigelarinihasilnya': 242,
#  'pernahterjebakdiliftanggotadprmintaanggaranperbaikankesrimulyani': 243,
#  'jangansalahkauskakiyangtepatuntukknitsneakersadalah': 244,
#  'agarmasyarakatbisamelayatbjhabibieaturanganjilgenapditigajalaninitakberlaku': 245,
#  'tawarkanponsellipatyangoutoftheboxperusahaaninitantangsamsungdanhuawei': 246,
#  'barbiekumalasariakuipunyasuarajazzycumabisadinikmatiyangbermusikalitas': 247,
#  'alasansuzukioptimistispenjualansemesterii2019membaik': 248,
#  'keluargakorbanpengeroyokanpolisimemintaperlindunganhukum': 249,
#  '10000orangdiwamenatelahmendaftaruntukdievakuasiusaikerusuhan': 250,
#  'pesertamagangdapatkarpetmerahjadipegawaipln': 251,
#  'beginijadinyaketikateslamodel3dimodifsuperceper': 252,
#  'anggotabpkakanditetapkanusaiujikelayakanterakhirselasa': 253,
#  '99namacintabukanfilmreligimeskimengambillatarkehidupanpesantren': 254,
#  'kuildithailandsembunyikanpuluhanbangkaiharimau': 255,
#  'tidaktakutgagal4zodiakinisukaambilrisikobesar': 256,
#  'beredarvideog': 257,
#  'dragonbigbangclubbingsambilmerokokdanmabuk': 258,
#  'mabukan': 259,
#  'aparatkembalisiagadijlgatsudekatgedungdprsiangini': 260,
#  'sandradewibikinirikarenatetapcantikdansingsetusaimelahirkan': 261,
#  'manchestercitypunyaskuattermahaldieropa': 262,
#  'akhirnyabesokjokowituruntemuiperwakilanmahasiswa': 263,
#  'kemarauwargacisaruasempatkesulitanmandikanjenazah': 264,
#  'alasanpemudapartaigolkardiymintawalikotayogyakartamengundurkandiri': 265,
#  'trumpkesepakatanperdaganganchinabisatercapaisaatpilpresas': 266,
#  'mantangubernurpapuabaratabrahamatururimeninggal': 267,
#  'andretaulanybeliharleydavidsonsportstersehargarp400': 268,
#  'anjutasetelahnabungselama25tahun': 269,
#  'plndorongpenggunaankendaraanlistriklewatkarnavaljakartalangitbiru': 270,
#  'beginiartinamaanakkeduasandradewi': 271,
#  'ada941pelanggarandiharipertamaperluasanganjilgenap': 272,
#  'thareqhabibiekesehatanbapakmulaistabil': 273,
#  'asusrilisduolaptopvivobookdenganbingkailayartipis': 274,
#  'pengembangdatabaseopensourcepostgresqlse': 275,
#  'asiaberkumpuldibali': 276,
#  'pro': 277,
#  'kontrapemindahanibukotabaruindonesiakekalimantanluhutkalaugakmaukesurgaaja': 278,
#  'setelahsuksesdiduniahiburanadlyfairuzjualankopi': 279,
#  'dampakkabutasaplionairgroupbatalkan21penerbangan': 280,
#  'viralselfiedimakambjhabibiebagaimanahukumnyadalamislam': 281,
#  'afghanistanserukantalibanterimagencatansenjata': 282,
#  'kondisiudarasemakinmemburuksekolahdidharmasrayadiliburkan3hari': 283,
#  'finiske': 284,
#  '11dimotogpsanmarinozarcocukuppuas': 285,
#  'terungkapcarakelvinmembakarmobilberisimayatpupungdandanaauliasiapkan8botolbensin': 286,
#  'transaksiimx2019ditargetkanlebihdarirp3miliar': 287,
#  'polisidalamipenyebarpesanberantaiyangajakpelajardemodimakassar': 288,
#  'rayakanharijadisavasagandengaeonstore': 289,
#  'kitkatgantikemasanplastikdengankertasorigami': 290,
#  'puanindustrispadapattingkatkanperekonomianlokal': 291,
#  'anggarankementerianpuprtahun2020disetujuirp12021triliun': 292,
#  'soalrevisiuukpkrelawannilailangkahjokowitepat': 293,
#  '10wisatajogjadanjawatengahdenganpanoramabaknegeridiatasawan': 294,
#  'kenalkanskuterhidrolikroda4canggihquadroqooderlistriksiapdiproduksi': 295,
#  '3tukangojektewasditembakkkbdiintanjaya': 296,
#  'singgungsoalmantandanikanasingalihginanjarmemangitufaktanya': 297,
#  'faozanrizalhabibie': 298,
#  'ainunbagairomeo': 299,
#  'julietindonesia': 300,
#  'sinopsissinetroncintabutaepisode126tayang16mei2019': 301,
#  'intelijenmiliterjermanperluaspenyelidikanpengaruhekstremkanandibundeswehr': 302,
#  'poppykellyngakusudahlaporkanbaliknikitamirzanihinggasiapkan13pengacara': 303,
#  'menhubharapkanpesawatr80jadikenyataan': 304,
#  'penuhgairahpetenisseksiiniciummesrapacarbaruusaigagaldiasterbuka': 305,
#  'bpkungkap14965masalahsenilairp1035triliun': 306,
#  'uukpkbaruberlakusejakdiundangkanjokowi': 307,
#  'digugatcalegkarenamenangkanmulancsgerindrasiapikutiproseshukum': 308,
#  'merawatsistemverifikasilegalitaskayu': 309,
#  'dinkesbatamimbauwargawaspadaikabutasap': 310,
#  'jksoalbanyaknyaottkpkkalaumakinkurangituprestasi': 311,
#  'kerusuhan22meivonis4bulanbuidisambutsukacitakeluarga': 312,
#  'pengendarayangtakbertanggungjawabharusdipidana': 313,
#  'finalaovstarleaguedigelarbesokpenontonbisadapathadiah': 314,
#  'wapresjusufkallasetujuadadewanpengawaskpktetapi': 315,
#  'klinsmanntakmengetahuileveltimnasjermansaatini': 316,
#  'botolairminumterpaparmatahariberdampakburukbagikesehatan': 317,
#  'bandaacehdiselimutikabutasap5000maskerdibagikankewarga': 318,
#  'luarbiasainimanfaataircucianberasuntukrambut': 319,
#  'pegawaikpksuratifraksididprmintatakpilihcapimyanglemahkankpk': 320,
#  'teukuwisnuterharuanakstmbentroktapiberhentisaatazanmagribbagikanvideomenyentuhini': 321,
#  'mantabberhijabdanbukausahafashioncutmeyriskainspirasininazatulini': 322,
#  'aniescabutkasasiperkaralahansodetanciliwungeraahokdima': 323,
#  'arumibachsinjadimodelcatwalkdadakancantikdanmempesona': 324,
#  'wapresjkjengukhabibiedirspad': 325,
#  'jelangtimnasu19indonesiavsiransayedakbarpoursanjungorangindonesia': 326,
#  'jikatakkunjungpenuhipanggilanveronicakomanbakaljadidpo': 327,
#  'ihsgmelemahpadasesiperdaganganpertamahariini': 328,
#  'irantangkaptigawargaaustralia': 329,
#  'polrestadepokbelumtelusurialiranuangptdamtour': 330,
#  'lucintalunabisniskopinetizenkritiknamabrandnya': 331,
#  'tradisiunik10muharramdinunukanbeliperkakasdapur': 332,
#  'kabutasapsirnadigempurhujanwargajambikinibisalepasmasker': 333,
#  'hasilligachampionsshakhtardonetskvsmanchestercity0': 334,
#  'ratuelizabethrupanyataksukalihatkatemiddletondanmeghanmarklepakaibendainididepanumum': 335,
#  'kemaraupanjangsejumlahdesadibalibaratalamikesulitanair': 336,
#  'narasibukusejarahkurangtunjukkanpercayadiribangsa': 337,
#  'resepcilokanti': 338,
#  'alotmengunyahtaklagisusah': 339,
#  'bjhabibiemeninggalduniaahyberbahagiakembalidenganbuainun': 340,
#  'walikotajambifashakembaliboyongpialawahanatatanugraha': 341,
#  'duaorangkorbanbentrokanditanahabangalamilukacukupparah': 342,
#  'sinopsisdramastill17episode3transformasiyangsejong': 343,
#  'responadikkandungbjhabibieseringditerpahoaxkabarduka': 344,
#  'dubesmalaysiahabibiebanyakmenyokongmalaysia': 345,
#  'timhondapenurunanperformalorenzobukankarenateknis': 346,
#  'livestreamingtvonlineindosiarpsmmakassarvspstirapersikabopukul1830wib': 347,
#  'kenaikancukairokokefektifturunkanjumlahperokokdiindonesia': 348,
#  'inipenyebabpetruccihanyamampufiniske': 349,
#  '10dimotogpsanmarino2019': 350,
#  'tertinggaljauhdarimarquezdimotogp2019doviziosopilihfokuspersiapkanmusimdepan': 351,
#  'bowosidikakuiperintahkandirekturperusahaanmiliknyauruspenerimaanfee': 352,
#  'jadikorbanperkosaankenapabarbienouvataklaporpolisi': 353,
#  'esemkajadimobildinasiniharapansekdajateng': 354,
#  'putuscintadengansangkekasihpesepakbolainggrisinipilihbunuhdiri': 355,
#  'fraksipartaigolkarmendadakrotasianggotadikomisixidpr': 356,
#  'imamnahrawitersangkajokowihati': 357,
#  'hatigunakananggaran': 358,
#  'attahalilintarpamitandaritelevisigara': 359,
#  'garaskandaldenganbebbyfey': 360,
#  '6zodiakinicenderungmenekandirisendiriuntukmencapaitujuanapakahkamutermasuk': 361,
#  'minggupagikualitasudarajakartaposisi3terburukdidunia': 362,
#  'rafaelnadalberpeluangperingkatsatuduniagesernovakdjokovic': 363,
#  'seagames2019jalanipelatnas3bulankickboxingsiaptanding': 364,
#  'sinopsisdramawepisode10leejongsukdijebaklakukanpembunuhan': 365,
#  'unjukgigibarengkomedianinternasionalmosidikjadilineupenglishshowjicomfest': 366,
#  'pelamarcpnskinibolehberusia40tahununtukposisiapasaja': 367,
#  'biancaandreescujadinamajalandikotakelahirannya': 368,
#  'legendaliverpoolsentilpenyerangmu': 369,
#  'habisdilantik80persenanggotadprdgunungkidulgadaikanskuntukpinjambank': 370,
#  'smartroadshow2019ajangmodenapamerprodukunggulan': 371,
#  'ruukuhpbisajeratkorporasipembakarhutan': 372,
#  'dibahastertutupdprdanpemerintahsepakatirkuhp': 373,
#  'menyerahkanpengelolaankpkkejokowidinilaitakbijaksana': 374,
#  'hengkangditengahpersainganchoibyungchanvictonbongkaralasangabungproducex101': 375,
#  'johnkenedyazizpastikantakadapertemuankomisiiiidenganampg': 376,
#  'imbanglawanpsmmakassarpelatihbadaklampungpuas': 377,
#  'michaelowensebutkualitasmudanliverpoolsetara': 378,
#  'fotopunggungkaiexoiniseringdikirajungkookbtsoleharmy': 379,
#  'walikotajakutkoordinasidenganpolisisoalambulansdidugabawamolotov': 380,
#  'ceritaanehdibaliklemariparamiliarderamerika': 381,
#  'usaiseranganhouthiarabsaudiupayakanpulihkanproduksiminyak': 382,
#  'alexandermawartamengakutakkesulitangarapmakalahcapimkpk': 383,
#  'barengjonatandanleeyongdaebikinnetizenkelepek': 384,
#  'kelepek': 385,
#  'kesepakatanmahasiswadengansetjendprtanpamaterai': 386,
#  'jadispecialguestminietvbayaranvanessaangelbisabuatbelipulau': 387,
#  'keluargamahasiwakorbandemokendaritolaktemuipolisidantuntutpenangkapanpelaku': 388,
#  'hanyapernah2kalifinalisligachampionsmusimsebelumnyaseburukini': 389,
#  'mengidappenyakitlangkadokterinilakukanpenelitianuntuksembuhkandirisendiri': 390,
#  '30orangjaditersangkakerusuhandipapuabaratdan12dpoiniperannya': 391,
#  'ggproductionsiapgelarlaunchingdanminikonsermanadogalau2disandjajarestokelapagading': 392,
#  '2rukopasarmodernbintaroterbakarpengunjungberhamburan': 393,
#  'tsunamisulitdiprediksiinikataahliyangharuskitalakukan': 394,
#  'disdikdansgekerjasamaberibeasiswakesiswa': 395,
#  '7tipsbelanjaonlinedenganamanagarterhindardaripenipuanhati': 396,
#  'hatisebelummembeli': 397,
#  'protesmoraleswargapukulpancidanwajandijendelarumah': 398,
#  'anwaribrahimberharapdudukijabatanpmmalaysiatahundepan': 399,
#  'ligachampionsrabuinipreviewolympiacosvstottenhamhotspur': 400,
#  'menerimahonordarimembacaalquranbagaimanahukumnya': 401,
#  'kpktepistudinganmoeldokosoalhambatinvestasi': 402,
#  'polisiamankanpelajarbawabatudalamtassaatdemodidprdsulsel': 403,
#  'imbasdemorusuhoperasionalbandarawamenadihentikan': 404,
#  'sidangpraperadilankivlanzensoalpenyitaanponseldanmobiltetapberjalandipnjakartaselatan': 405,
#  'perhatiandipolatiefpadanikitamirzaniupdateusganak': 406,
#  'inginbiayailahiran': 407,
#  'bantingtulangjadiojolpriainihisterissaatpulangkerumahkenyataanpahityangbisabikinbunuhdiri': 408,
#  'satpolppawasipencarisuakayangkembaliketrotoarkebonsirih': 409,
#  'johnkrasinskiumumkanaquietplace2rampungkanprosessyuting': 410,
#  'oppoklaimseriajadiprimadonadipasarindonesia': 411,
#  'hadirinewyorkfashionweekhadiahkehormatanpemenangtresemmetherunway2019': 412,
#  'akandikenaipasalmakarbuchtartabuniditangkappoldapapua': 413,
#  'raihhasilburukdisilverstonequartararoberambisibangkitdimotogpsanmarino2019': 414,
#  'umjig': 415,
#  'friendpostingfotocantiknetizensebutoplasberhasilsindirjooemomoland': 416,
#  'sofyandjalilancamspekulantanahbisadijeratpidana': 417,
#  'bkpmsebutkanlimakeluhaninvestorkepadaindonesia': 418,
#  'aksihyunapamercelanadalamjadikontroversinetizenngototsebutbukanpenyanyi': 419,
#  'hargadagingayamdipurwakartafluktuasi': 420,
#  'sakitperutmelilitcobaatasidengan7bahanalamiini': 421,
#  'jenderalasakuikekuatanmiliterrusiatelahlampauinato': 422,
#  'mncsekuritasresmikangaleriinvestasibeiuniversitasriaukepulauan': 423,
#  'maiacantikberhijabumrohbarengsuamipakaijetpribadibarusyahrinidiledekkejang': 424,
#  'lokasiibukotabarubebaskarhutala': 425,
#  'wajahdanleherbelangbedakteballeedaehwiab6ixbikinnetizenemosi': 426,
#  'pengadilanagamadomputerapkanlayananberbasisaplikasi': 427,
#  'top3teknohargasamsunggalaxya50sbikinpenasaran': 428,
#  'suzukiaturankeringananuangmukabisadongkrakpenjualanmobil': 429,
#  'inilahenamwakilindonesiadalamperempatfinalchinaopen2019': 430,
#  'garahalsepeleinisiswasmpdimagetantusuksahabatsendiri': 431,
#  'pakarhukumharappubliktakributkandewanpengawaskpk': 432,
#  'majelisrakyatbelumcabutseruansiswapapuaagarpulang': 433,
#  'deddycorbuzierpamerfotogagahberotothinggaramaidisangkapatungmanekin': 434,
#  'kpkmintadprtundapengesahanrevisiuukpk': 435,
#  'grupk': 436,
#  'popseventeenpecahkanrekorpenjualanalbumanode': 437,
#  'sosokbjhabibiedalamkenanganasistenpelatihbaliunited': 438,
#  'setujusoalkontrakpolitikfahrihamzahagarkpktaat': 439,
#  'wirantosebutpotensiadanyagerakanislamradikalgariskerasyangsusupiaksidemo': 440,
#  'bayarpbbdibukalapakbebasbiayaadmininikodevouchernya': 441,
#  'krisisglobalsentimennegatifbagipergerakanihsg': 442,
#  'total6terdugateroriskelompokjadditangkaptimdensusdibekasi': 443,
#  'chenexobeberkanperasaanberalihkegenreretrodilagucomebacksoloshallwe': 444,
#  'idappenyakitserius4artisinitakgengsipakaibpjskesehatanuntukberobatdirs': 445,
#  'rupiahsiangmenguatterbatassaatihsgjatuh2714poin': 446,
#  'sinopsissinetroncintasucitayangrabu9mei2019': 447,
#  'basukisindirditjenbinamargamalasbangunterowongan': 448,
#  'habibiesempatkannonton3filmadaptasinovelasmanadia': 449,
#  'inirincianskemabiayapembangunanibukotabaru': 450,
#  'walkothendiberencanaterapkan': 451,
#  'carfreezone': 452,
#  'dikotalamasemarang': 453,
#  'tbbmpertaminarewulubinadesagamoljadiekonomiramahlingkungan': 454,
#  '4tipsmendakigunungdimusimkemarauwaspadaadakebakaran': 455,
#  'eramobillistrikdatangasuransiastrasedangkamikalkulasi': 456,
#  'inijumlahtotalkarakterutamadimangaonepiece': 457,
#  'sempatdianggappencitraanhinggadiremehkanawkarinkinipamersenyumlebargara': 458,
#  'cetakquat': 459,
#  'trickkegawanglithuaniaronaldocetakrekor': 460,
#  'polisisebutbomtatpmilikterdugaterorisdijakutberdayaledaktinggi': 461,
#  'denganposeksporbeacukaidorongumkmtembuspasarluarnegeri': 462,
#  'rasainginmemilikibelumtentuartinyasamadengancintasejati': 463,
#  'dprddkibelumpunyapimpinandemokrattunggukeputusansby': 464,
#  'fadelmohammaddorongbupatigorontaloterusbekerja': 465,
#  'tigaasteroidmelintaskemarindanpagiinibagaimanadampaknyauntukbumi': 466,
#  'munculusulandkigunakanduawagubmungkinkah': 467,
#  'munasdinilaibisajadireformasipartaigolkarjilid2': 468,
#  'laguanggunterusmerangseknaikdibillboarddancechartas': 469,
#  'daihatsusigrabarumeluncurhariiniadaperubahansignifikan': 470,
#  'grupkeuangankorselguyurrp35055miliarkeindonesia': 471,
#  'relapanas': 472,
#  'panasanandovidalopeztanampohondibentengvandenbosch': 473,
#  '5ambulancedkidisebutbawabatudanbensininijawabanelegananiespostinganpoldametrolangsungdihapus': 474,
#  'masintonmintakritikatascapimkpkdilengkapidata': 475,
#  'hotmanparisberiejekanfarhatabbascumabisanongoldiigpadahalmangkirdaripanggilanpolisi': 476,
#  'thiaajakkaumibuikutiseminarparentingbersamakakseto': 477,
#  'barupertamakaliliburanketurki1harikelilingistanbulbisajadipilihan': 478,
#  'beritapopuler': 479,
#  'polisinikitamirzanibukaninforman': 480,
#  'permintaanterakhirbocahfathirahmad': 481,
#  'kpktanggapidprpenegakanhukumtakbolehterikatkomitmenpolitik': 482,
#  'headlinejanjijokowiuntukpapuadamaidibumicenderawasihbakalterwujud': 483,
#  'viralkecelakaanbusmiranganjuk': 484,
#  'madiunkorbanselamatburonannarkobasudahditahanpolisi': 485,
#  '5tahunmerantaudijakartaakankahfendychowmemenuhiharapansangibu': 486,
#  'polisipemukulanggotadprdsumutdiamankanf': 487,
#  'gerindraakankonfirmasi': 488,
#  'imlowapresiasieksporulangkontainerlimbahplastikimpor': 489,
#  'sumseldikepungasapgubernurpergikunkerkemalaysia': 490,
#  'lunamayadimintasangcalonmertuatakcemburusaatdisuapifaisalnasimuddinfansgirang': 491,
#  'dihadapanpbbpakistanperingatkanancamangenosidadikashmir': 492,
#  'wengermenyesalgagalboyongmessikearsenal': 493,
#  'rusiatahanduakapalkoreautarasalahsatunyalepaskantembakan': 494,
#  'mudahnyachefselebritasajarkantipssederhanamemasak': 495,
#  'bappenasingatkankemenpartaksekadarkejarjumlahwisman': 496,
#  'ngeribakterisekarangbisatemukancarauntukkebaldariantibiotik': 497,
#  'srimulyanipantaudurasidisrupsiakibatsaudiaramcodiserang': 498,
#  'sonysubratadukungpemerintahtegasterhadappenyediamedsos': 499,
#  'rommybantahdakwaankpksoalintervensimenagbukananakbuahsaya': 500,
#  'moveonini5tandamantantakakanmengajakmubalikan': 501,
#  'rkuhpdendagelandanganmaksimalrp1jutainiceritaparapengemistajir': 502,
#  'boywilliamrayakanulangtahunmendiangadiklewatpostinganmengharukanini': 503,
#  'cukairokoknaik23': 504,
#  'indonesiarentanrokokilegal': 505,
#  'bmkgjabodetabektidakdiguyurhujanhariini': 506,
#  'mengenangchrisyekenapakaryasanglegendaristakpernahmati': 507,
#  'ihsgturunhingga182': 508,
#  'padajedamakansiang': 509,
#  'srimulyanibeberkanalasancukairokoknaik23': 510,
#  'di2020': 511,
#  'rasioutangluarnegeriindonesiaterhadappdbmenurun': 512,
#  'citacitatatuaiberbagaikomentarusaicurhatpanjangtakterimadifitnahsombongolehpenggemar': 513,
#  'biasadipujicantikbellahadidmendadakdisebutgantenggara': 514,
#  'garatampilsepertiini': 515,
#  'arilassogelarkonsertunggalsetelah27tahunberkiprah': 516,
#  'jalantolkunciranserpongditargetkanbeoperasiduabulanlagi': 517,
#  'penataantrotoarcikiniberbasisbudayasepanjangjalurtimdibuatmural': 518,
#  'mengalamikdrtbeginifaktatigasetiagara': 519,
#  'memasukipuncakkemaraubmkgprediksisuhusurabayabisa35derajat': 520,
#  'cetakduagolkegawangestoniababelsangatmenyenangkan': 521,
#  'seksinyapacarcristianoronaldogeorginarodriguezsaatsesifotobusanatransparan': 522,
#  'datangkepapuamendagriprioritaskansinkronisasiprogramtepatsasaran': 523,
#  '7unggulanindonesiamasukjalurnerakadichinaopen2019': 524,
#  'digitalisasisekolah38sekolahdinatunaakandiberi': 525,
#  'tablet': 526,
#  'pembobolanbankpakaikudo2buronterlacakadadi': 527,
#  'targetinvestasipertaniannaikizininvestorharusdipermudah': 528,
#  'menangislahkarenainimanfaatmenangisuntuktubuh': 529,
#  'ridwankamilsebutimammasjiddinewyorkjadiinspirasiprogram': 530,
#  'englishforulama': 531,
#  'pilkadatangerangselatankpuanggarkansantunankppsmeninggal': 532,
#  'terdugaterorisyangditangkapdensus88dijakutrencanakanpengeboman': 533,
#  'jokowihabibieisastatemanrespectedbypeople': 534,
#  'vickyprasetyodiam': 535,
#  'diamdekatisaritaabdulmukti': 536,
#  'iniprodusenkomponenlokalyangsokongproduksimobilesemka': 537,
#  'zodiakkesehatanbesokramalanzodiakkesehatanrabu11september2019tauruslelahscorpiostres': 538,
#  'persibvssemenpadang1': 539,
#  '1benarkahadaupayawalkout': 540,
#  'siapkansdmindustriberkompetenri': 541,
#  'singapurakerjasamapendidikanvokasi': 542,
#  'pesonaarielnoahdiulangtahunke': 543,
#  '38gantengnyagakluntur': 544,
#  'tidakmelakukankesalahanapa': 545,
#  'apabocah4tahuninidianiayaibutirihinggatewas': 546,
#  'ceritasoalbjhabibiedankrisis1998': 547,
#  'kronologibusmiravsmobilinnovasatukorbanselamatburonankasusnarkobainiidentitasnya': 548,
#  'jelangmusimhujanpemkotjaktimbeli10pompamobilemini': 549,
#  'dinaskesehatandanpendidikandimintabantusekolahyangterdampakasapindustridicilincing': 550,
#  'prakiraancuacabmkg33kotabesokjumat20september2019jambidansamarindadiselimutiasap': 551,
#  'sinopsissinetronorangketigatayangjumat3mei2019': 552,
#  'kpaitemuipelajarkorbandemosebutadadugaandipukulipolisi': 553,
#  'sinopsis100daysmyprinceepisode5jasadputramahkotaberhasilditemukan': 554,
#  'pencarisuakakembalitempatitrotoarkawasankebonsirih': 555,
#  'panas': 556,
#  'panas5minumanesasliindonesiainibikinsegar': 557,
#  'mahasiswaprotesuukpkdanrkuhpdprjanjipertemuanlanjutan': 558,
#  'masalahsemakinpanjangfairuzarafiqpernahalamikdrtdengangalihginanjar': 559,
#  'hasilmotogpmarquezjuaradikandangrossi': 560,
#  'gempam53guncangpapuabarattakberpotensitsunami': 561,
#  'artikeltentangbtssinggungkematiantragisjonghyunshineepicukemarahanfansk': 562,
#  'pop': 563,
#  'ikutgeramdengandpranjidukungdemomahasiswauntukwakilisuararakyat': 564,
#  'mercedesluncurkanmobilpertamaformulae': 565,
#  'pembunuhsalesmotoryangmayatnyaterjerattalitambangdihutandibekuk': 566,
#  'linkajapermudahpembayaranpbbdkijakarta': 567,
#  'ketikagusdurngakutakkenalbjhabibiebercandaatautidak': 568,
#  'rupiahmenguatihsgnaikkelevel637281': 569,
#  'nikitamirzanibanggatakperlujadicabe': 570,
#  'cabeanasyikhitunguangsawerannyanyidiklubmalam': 571,
#  'sebentarlagihondazoomerdirilisdiindonesiabanderolnyadibawahpcx': 572,
#  'previewliga1tirapersikabovspersibbandung': 573,
#  'ramalanzodiakbesokrabu11september2019ariesberistirahatlahtaurushati': 574,
#  'hatilebihboros': 575,
#  'ellysugigiputuskanpakaihijabbeberkanalasandansempatkhawatirakansepijobintipfotonya': 576,
#  'dibantaipsgrealmadridtelanrekorterburuksejak2003': 577,
#  'masyarakatakaliperluasanganjilgenapdenganplatnomorpalsu': 578,
#  '7manfaatbangunpagiuntukkesehatanfisikdanmental': 579,
#  'polisidimeksikotemukan44mayatyangdimutilasi': 580,
#  'setelahbertengkarlucintalunadanraffiahmadfotobareng': 581,
#  'soallivizhenginikataernestprakasa': 582,
#  'grupbarujypboystorydikritikhabis': 583,
#  'habisanusainumpangtampildik': 584,
#  'conthailand': 585,
#  'pindahibukotapengaruhiaruserakendaraanlistrik': 586,
#  'hotmanparismendadakpajangfotomesrasyahrinikelewatlangsinglagikangen': 587,
#  'viralbayiperempuaninidiberikopikarenaorangtuatakmampubelisusu': 588,
#  'dutertexitawarkanperjanjiangasjikaabaikanarbitrase': 589,
#  'iniamalansebelumsalatistisqauntukmintahujan': 590,
#  'waduhsebagianlampulalulintasdipurwakartamati': 591,
#  'bnisyariahresmikanpembentukanjespalembang': 592,
#  'kimkardashiansempattundamelahirkannorthwestdemimanicure': 593,
#  'hinodukunginvestigasikecelakaanmautdicipularang': 594,
#  'thepressmorallyindebtedtohabibie': 595,
#  'gebbyvestablak': 596,
#  'blakanakuidirinyatransgendermenangisungkapalasan19tahunsembunyikanfakta': 597,
#  '4inovasirumahpintaryangbikinandatenangsaattinggalkanrumah': 598,
#  'pendirikaskusandrewdarwisdilaporkanataskasuspemalsuan': 599,
#  'mesrasekalilihataksidariussinathryagendongdonnaagnesia': 600,
#  'hotnewsdicidukpolisinunungpositifpakainarkoba': 601,
#  'ditjenpas': 602,
#  'bnptbahas587napiterorisdirjenpasiniharusjadiperhatiankhusus': 603,
#  'perundingandamaias': 604,
#  'talibanruntuhpakistankecewaberat': 605,
#  'jelangputarankedualiga1pemainsemenpadangjalanitesvo2max': 606,
#  'gojekresmiberoperasidibandarasoekarno': 607,
#  'hattabeginicarapesannya': 608,
#  'surijabrikgadiscantikkeponakanlunamayayangternyatajagosurfing': 609,
#  'dianggaprasisgoogletranslatemintamaafkerakyataceh': 610,
#  'tampilmengenakanhijabawkarinhijrah': 611,
#  'ceritamatanajwakirimundanganterbukakeketuadpr': 612,
#  'selandiabarulawanpenyebarankontenterorismedimedsos': 613,
#  'lapakbijihplastikdilalapsijagomerah15mobildamkardikerahkan': 614,
#  'sukanontontapienggakadawaktucobain8aplikasistreamingfilmdandramaterpopulerini': 615,
#  'rezarahadianinginkanlebihbanyaklayardimomentumharifilmnasional': 616,
#  'linklivestreamingtimnasindonesiavsthailanddikualifikasipialadunia2022pukul1930wib': 617,
#  'pemancinginitaksengajatangkapikan': 618,
#  'alien': 619,
#  'bermatabesar': 620,
#  'samsungboyongtime': 621,
#  'sport': 622,
#  'detonator': 623,
#  'ketgs2019': 624,
#  'sudahdamaimelaneyricardoceritakanelzasyarifsempatsyok': 625,
#  'takbisamakan': 626,
#  'burungkolibripenyambungrantaikehidupandibangkabelitungterancampunah': 627,
#  'awkarinternyatasempatdiremehkansaatmendadakpesan3ribunasikotakuntukpendemo': 628,
#  'pemkabdharmasrayaakanperingatiharimaritimnasional': 629,
#  'hargaminyakmeroket15': 630,
#  'usaifasilitasminyakarabsaudidiserang': 631,
#  '6caramediasosialmerusakhubunganmudenganpacar': 632,
#  'dibutuhkankomitmensemuapihakagarpariwisatamaratuamendunia': 633,
#  'aksipemakamankpkpuisibungadantembokwidjithukulmenggema': 634,
#  'ngevlogbarengnagitatakjubputrarubenonsusopanciumtanganhinggarajinsekolah': 635,
#  'gandhifernandoejekartisskuterbalikbelabarbiekumalasariusaiikut': 636,
#  'ikutannyindiradaapa': 637,
#  'datadidugabocorpemilikakunmileslionairdiimbauubahsandi': 638,
#  'sinopsissinetronanaklangitepisode1101tayangkamis18april2019': 639,
#  'lampardpelatihchelseapertamayangalamikekalahandilagadebutligachampions': 640,
#  'perusahaansawitmalaysiadisegelterkaitkarhutlariau': 641,
#  'postingfotodengantagarproudofakadivangunawansudahnikah': 642,
#  'kpktepispernyataanmenporabelumterimasuratpanggilantersangka': 643,
#  'projosoalrevisiuukpktidakadawewenangkpkyangdikurangi': 644,
#  'berhentilatihansaatazanberkumandangbtsbanjirpujiandariparaarmy': 645,
#  'kyliejennerumumkankesehatannyamembaiklewatpostingansuperseksiini': 646,
#  'penambahan10pimpinanmprbentuknyatakongsipolitik': 647,
#  'diansastrotamparbalikkritikanmenteriyasonnasujiwotejopujiputrireformasi': 648,
#  'diseranghouthipakaidronekeamanankilangsaudiaramcorapuh': 649,
#  'tanyakanhaltakpantaspadabtsreporterinidihujatnetizen': 650,
#  'ancamankeindustrikeuangandiindonesiamakinbesar': 651,
#  'bemsigelaraksijelangpelantikandprlakukaninidemicegahpenyusup': 652,
#  'gunungslametmasihberstatuswaspada': 653,
#  'urusantransfermusiapmenggiladibursamusimdingin': 654,
#  'lifterindonesiaasahkekuatanjelangseagames': 655,
#  'adadolarsingapuraterbaruedisiterbatasinginmemilikinya': 656,
#  'attahalilintarejekbebbyfeypembohongpansosbajucouplebuktiberjodoh': 657,
#  'turkisebutastundapembentukanzonaamansuriah': 658,
#  'nagitaslavinatentengtaskulitbuayanettersibukhitungangkanolsaattahuharganya': 659,
#  'hanstraykidssuksesbikinfansmelelehusaiucapkankalimatromantisini': 660,
#  'faktamenarikgirlbandkoreaselatanmomoland': 661,
#  'richbriandannikisiaptampildihadapanpublikindonesia': 662,
#  'seventeenjanjilakukanhalkocakinijikadapatfirstwinuntuklagucomebackfear': 663,
#  'ceritajokowisoalhargabbmdansemendipapua': 664,
#  'dprdijadwalkansahkanrevisiuukpkhariini': 665,
#  'lerenggunungagungkembaliterbakar': 666,
#  'habibiesempattanyaanaknyasoalhoaksdirinyameninggal': 667,
#  'liga1rabuhariiniprediksipsmmakassarvspsissemarang': 668,
#  'yukperhatikanasupanibuhamildananak': 669,
#  'capekbohonglucintalunatampilawut': 670,
#  'awutanhingganangissaatungkapjatidiri': 671,
#  'menteripanrbmintauniversitascetakgenerasiunggul': 672,
#  'raziamirasdiwonogiripetugassitapuluhanbotolciu': 673,
#  'pemprovberipendampinganhukumkepetugasambulansyangdiamankanpolisi': 674,
#  'jamesharapbisatampilmaksimalbersamamadridmusimini': 675,
#  'antropologuntukindonesiatolakpelemahankpk': 676,
#  'persiapanmepetrinamubalarumtetaphadirkankoleksiglamourdiifw2019': 677,
#  'tigaprovokatorbentrokandijembatanbongkarantanahabangditangkap': 678,
#  'prillylatuconsinapelukmesrarezarahadiandanungkapharapanberjodoh': 679,
#  'sandiagaresponskemungkinandirinyakembaligabunggerindra': 680,
#  'maujadicalonwalikotatangselkolonelbebensiapmundurdaritni': 681,
#  'bursatransferliga1baritoputeradatangkan2mantanpemainnya': 682,
#  'jarakpandangkotapekanbaruturundrastisakibatkabutasap': 683,
#  'kadisbudparpastikanmuseumbentoeltidakmasukcagarbudaya': 684,
#  'padupadanjeansala4hijabersternamainibikinkamutampilstylish': 685,
#  'rumahtinggalterbakarakibatregulatortabunggasbocor': 686,
#  'sinarmaslandsiapkanbsdjadisiliconvalley': 687,
#  'nyaindonesia': 688,
#  'lagigayagitarisfingerstylealipbatapukaumusisitersohoraddiemsinginbertemu': 689,
#  'kronologidugaanpenipuanyangmenyeretnamapendirikaskus': 690,
#  'antamsabetpenghargaangoldpadasdgslewatkopihalmahera': 691,
#  'sejakakhir2018ambulansgratisjangkau805wargasukabumi': 692,
#  'makalahkananiesbaswedansoalsengketaeksbentenggudangpelurucakung': 693,
#  'kendaraantambangdimintagunakanb20': 694,
#  'kadopernikahanjustinbieberjamtanganmewahseharga1miliar': 695,
#  'anandabadudugalangdanademorp175jutadiciduktagarsaveawkarinjadisorotan': 696,
#  'dprdanpemerintahbahaspenambahanjumlahpimpinanmpr': 697,
#  'polemikpbdjarumvskpaiyangberujungstopaudisi': 698,
#  'sullibelahatfeltbukancaperusaibongkarchatmantanmalahdisambutnyinyiran': 699,
#  'kuhyesungencarjualanbukuusaidigugatceraiwawancarabarutuairesponssinis': 700,
#  'viralseorangpengendarakeluarkanjurussilatsaatkenaraziapolisi': 701,
#  'billysyahputraterjebakdemoyangberakhirricuhsempatdiomeligara': 702,
#  'garaabadikanmomenkerusuhan': 703,
#  'trukhilangkendalidichina10orangtewas': 704,
#  'ajakanak': 705,
#  'anakhidupsehatsiswismaciptakangamehygienerush': 706,
#  'dinilailakukanpembangkanganmassampkberikartumerahkepadakpk': 707,
#  'bahayakanpenerbangan250litermirasdan117powerbankdimusnahkandibandarasamratulangi': 708,
#  '19hadiahuntukcalonatauibumertuayangsulitditaklukkan': 709,
#  'duapekanperluasanganjilgenapadapengendarabelumtahu': 710,
#  'seleksicapimkpknawawibakpulangdugemjalansempoyongan': 711,
#  'demersongantikanposisiamevordiperselalamongan': 712,
#  'smartsimdiluncurkanwakapolriharapbisamemudahkanpengendaralalulintas': 713,
#  'kemenkeudorongpesertabpjsdisiplinbayariuran': 714,
#  'sebelumyogasebaiknyahindarimengonsumsi4makananini': 715,
#  'jawabisuphkbukalapakberdalihinginraihkeuntunganpertama': 716,
#  'wartawankorbanpemukulanaparatdimakassarlaporkepropampoldasulsel': 717,
#  'nagitaslavinaterlaluseringpakaibarangmewahhargasandalkaretseginidibilangmurah': 718,
#  'laodesebutmasatergelapkpkusairevisiuukpknajwashihabsyokbertanya2kalidengarfaktaini': 719,
#  'petugasdishublaporkanaksipemukulandriverojoldisenenkepolisi': 720,
#  'tnitunjukputraaslipapuajadipangdamcendrawasih': 721,
#  'tipetemansepertiapakahkamucobaikutteskepribadianini': 722,
#  'rupslbbankbtpnsetujuiperubahansusunandireksi': 723,
#  'perangnarkobaguatemalakirim2000tentarakeperbatasan': 724,
#  'masyarakatadatpapuabutuhkepastianhukumpengelolaanhutan': 725,
#  'napolidanliverpoolsamakuatdibabakpertama': 726,
#  'korbaninvestasiuangdigitalnasabahditangseltertipurp35miliar': 727,
#  'indiabikinkompetisikentutterpanjangdanterkerasmauikutan': 728,
#  'mereknasionalpemerintahmaklumiesemkabimahanyagantimerek': 729,
#  'jamaahhajisuluttibadibandarasamratulangimanado': 730,
#  'senininikpkpanggilmelchiasmarcusmekengsebagaisaksi': 731,
#  'tolakruupertanahanribuanpetanisiapgelaraksidiistana': 732,
#  'dpresok': 733,
#  'kebakarandiapartemenkalibatacityduapenghuniluka': 734,
#  'tuntutditemuianggotadprdmahasiswainjakkawatberduridanlemparbotol': 735,
#  'inisebabtinggibadangabbyterusbertambahhinggacapai22meter': 736,
#  'vebbypalwintaakuisudahbelajartaarufsiapsegeranikah': 737,
#  'kabutasapbuatwargapadangsidimpuansumutmengap': 738,
#  'mengap': 739,
#  'bappenastegaskananggaranibukotabarutidakmasukrapbn2020': 740,
#  'menakerpemerintahsiapkanperlindunganskilldanjaminansosialbagipekerja': 741,
#  'hasillengkapligaitaliapekanketigadanklasemen': 742,
#  'laporkekomnashamikatanmahasiswasebutpolisialatpembunuh': 743,
#  'munculikananehdenganmataraksasainipenampakannya': 744,
#  'sinopsissinetroncintasuciepisode295tayangsenin1april2019': 745,
#  'fahrihamzahusulkanpresiden': 746,
#  'dprlakukanrapatkonsultasiruukuhp': 747,
#  'ratusankilosampahtertimbundipantaigoldcoast': 748,
#  'pencurianmobildinasemildidugaadaindikasiorangdalam': 749,
#  'dukungbisnisonlineposindonesialuncurkansamedayservice': 750,
#  'tigabulan400tangkiairdikirimkewargalamonganatasikekeringan': 751,
#  'lunatakcumajualankosmetiktapijugabukajasalesnyanyidanmainmusikbeginikatanetizen': 752,
#  'kisahpembunuhbayaran': 753,
#  'kelasteri': 754,
#  'relamembunuhasaldibelikanrokok': 755,
#  'kissmerasadirugikandanmarahsaatharusmeninggaldiclassofliesfansmalahgemas': 756,
#  'habibiewafatlibwacanakanpenggunaanbanhitamdilengan': 757,
#  'berikanpendampingankeluargakemenpppakembangkanpuspaga': 758,
#  'kondisibjhabibiesemakinmembaik': 759,
#  'tabrakanberuntunduamobildanduamotorterjadidilentengagung': 760,
#  'sebanyak6025wargakalbartercatatmenderitaispa': 761,
#  'rupiahdibukamerangkaknaikusddekatileveltertinggiversusyen': 762,
#  '18sskbrimobmasihdisiagakandipapuabarat': 763,
#  'nyamarjadiemakemakberdasterpolisiiniberhasiltangkapbegalsadis': 764,
#  'massapetanidemodigedungdprdsumuttolakpengesahanruupertanahan': 765,
#  'dukungpembangunannasionaldenganpenguatanjabatanfungsional': 766,
#  'rusiakembangkandronesilumanraksasaberbobot22ton': 767,
#  'didampingibudigunawanjokowidengaraspirasidaritokohpapua': 768,
#  'seimbangkankeuanganmusimakpesanmalaikathariini': 769,
#  'pekankeempatoktober2019nilaikapitalisasipasarrp7190749triliun': 770,
#  'inagurasibinusdiikutilebihdari12ribumahasiswabaru': 771,
#  'menkesnilaipenanganankesehatanhajitelahberhasil': 772,
#  '15pasanganselebkoreayangcinloktakberakhirbahagiaputus': 773,
#  'bkkbnfokuskanpelayanankbdiperbatasanjateng': 774,
#  'jatim': 775,
#  'peluncurandarkmodetwitteruntukhandphoneandroidditunda': 776,
#  'kemenkeugandengpolisiawasirokokilegal': 777,
#  'profesorcinadituduhcuriteknologiperusahaanasuntukhuawei': 778,
#  'penurunanuangmukakpr5': 779,
#  'hanyauntukrumahkedua': 780,
#  'karenaasapsiswasekolahdikampardipulangkandipagihari': 781,
#  'gagalnaikpodiumdimisanodoviziosotetaptenang': 782,
#  'mnkahmihanyarsaddamaljihadketuaumumpbhmiyangsah': 783,
#  'pkbberibantuanhukumkepadamenpora': 784,
#  'menkoluhutmasyarakatniasharussiapkandirisambutwisatawan': 785,
#  'valenciapecatpelatihjelanglagamelawanbarcelona': 786,
#  'intippernikahanalawargamalaysiabakdinegeridongeng': 787,
#  'munaslubmkgrsempatricuhpolisipastikansituasisudahkondusif': 788,
#  'inflasididesaterjagadayabelipetanirinaik': 789,
#  'houthibersiapseranglagifasilitasminyakarabsaudi': 790,
#  'habibiewafatr80diusulkanjadiproyekstrategisnasional': 791,
#  'pabriktinerdikalideresterbakar15mobildamkardikerahkan': 792,
#  'gunungslametterbakarpuluhanpetugasditerjunkanpadamkanapi': 793,
#  'meme': 794,
#  'memekocakhidupbersama': 795,
#  'aniesberharapajanglarijakartakizunaekidenpererathubunganri': 796,
#  'jepang': 797,
#  'capimkpklilipintaulisayatidaksetujudewanpengawas': 798,
#  'hasilakhirtimnasindonesiavsthailandskuatgarudakalah0': 799,
#  'dampakgempam68diambonjembatanretak': 800,
#  'kampusrusakringan': 801,
#  'temuilaodemsyarifrektoripbberidukunganuntukkpk': 802,
#  'pencabutansubsidilistriktunggupengesahanapbn2020': 803,
#  'iuranbpjskesehatanbakalnaikombudsmankesalahansejakawal': 804,
#  'agnesmonicaajarimakiankasardalambahasaindonesiakebulejustrutuaipujian': 805,
#  'kementanpenangkapanpetaniacehsudahtepatdemimelindungipetanijuga': 806,
#  'pan¬†beberkan¬†janji': 807,
#  'janjianiesbaswedanyangbelumterlaksana': 808,
#  'sandradewiakhirnyapamerwajahmikhaelmoeisgantengbanget': 809,
#  'takbanyakyangtahuagungherculespernahberperanjadimilkymandisaras008': 810,
#  'pompeoseranganterhadapkilangminyaksaudiaksiperangiran': 811,
#  'djkattybutterflykabarkansangibundasakitwajahcantikadikcuriperhatian': 812,
#  'demodikedubesaustraliamahasiswadesakmabespolritangkapveronicakoman': 813,
#  'hargaminyaknaikusaiserangankesaudiaramco': 814,
#  'anaktidakmaumakannasiapakahberbahaya': 815,
#  'kabutasapkianpekatdinkeskobardirikanrumahsinggahoksigen': 816,
#  'upayakemnakertingkatkankompetensidankapasitasparatrainer': 817,
#  'penguatansdmmahasiswaasalpapuajadiwacanaperguruantinggidijawabarat': 818,
#  'hargaemasduniaturununtuk3hariberuntunapasebabnya': 819,
#  'pemerintahdandprsetujurevisiundang': 820,
#  'undangmd3': 821,
#  'wirantobicarakanpermasalahanpapuasaattemuieksmenlufiji': 822,
#  'raffiahmadtakterimamerrykerjaikutbudendymantanasistenbuatpengakuansumpahdemiallah': 823,
#  'btnpederelaksasiltvbakalpacupenyalurankprnonsubsidi': 824,
#  'polisikesulitantelusuridugaanterorulardiasramapapua': 825,
#  'caramenyimpantwitoranglainditwittertanpaketahuanfollower': 826,
#  'bpjsdefisitrp32triliunwamenkeukitaterlaludimanjasakitsedikitlangsungkers': 827,
#  'gerindrasetujuwacanawagubdkijakartalebihdarisatutapi': 828,
#  'dprakansahkanruuperkawinanbatasusiaperkawinanjadi19tahun': 829,
#  'pangeranharryberitandameghanmarklesudahmelahirkan': 830,
#  'jlgatsudekatdprditutupkendaraandialihkankejlgerbangpemuda': 831,
#  'bursatransferpemainliga1semenpadangtambah4pemainbaru': 832,
#  'hotmanparisngakumaindifirstclasspascafarhatabbaspamerlagidiswisslucumenggelikan': 833,
#  'jualrumahdemishakirakediamandenadaditawarkeluargamenteridenganhargasegini': 834,
#  'jajalmobillistrikanieskonvoimobilmewahbersamapebalapseangelael': 835,
#  'daihatsusigra2019masihpakaiaircirculatorbukanacdoubleblower': 836,
#  'trumpsiapbertemurouhanitanpaprasyarat': 837,
#  'kemenhubsiapkerjakankeretacepatjakarta': 838,
#  'surabaya': 839,
#  'yuhugrabpunyahalbarudiakhirtahunini': 840,
#  'viralpersamaangayakaiexodankrystalf': 841,
#  'bikinfansbapersendiri': 842,
#  'anggotakomisiiiipdippersilakancapimkpklobi': 843,
#  'lobi': 844,
#  'uberphk435karyawanbagianproduksidanteknik': 845,
#  'hebohsyahrinidanlunamayasepanggungbarengdishopeeramadantvshow': 846,
#  'hadapikentomomotadibabakkeduatommyharapbisatampilmaksimal': 847,
#  'besokpolisipanggilketumfpiterkaitkasusdugaanmakar': 848,
#  'pmselandiamintamaafatasskandalkekerasanseksualpartai': 849,
#  'lewatsenianak': 850,
#  'anakakantampilpercayadirihinggadewasa': 851,
#  'tanggapiserangandronekepabrikminyaksaudiaramcotrumpassiapmenembak': 852,
#  'wargadananggotatni': 853,
#  'polridimeranginjambisalatistisqa': 854,
#  'sriwijayaairdimintapatuhiksmgarudaindonesia': 855,
#  'pelajardemorusuhdidprbemunjsemogainibukandimanfaatkanoknum': 856,
#  'ulamasayangkanagendapolitikgunakansumpahalquran': 857,
#  'viralayahmarahianaknyayangikutdemotuaiprodankontra': 858,
#  'bajakahantaraobatdanracunsertakeikhlasanwargaibukotabaruindonesiamemberikannyagratis': 859,
#  'suzypostingekspresiseriusdivagabondmalahditanyasoalresep': 860,
#  'hincasbymintakaderpdpastikanpemerintahanjadilebihbaik': 861,
#  'kasussuapimporikankpkcegah2orangkeluarnegeri': 862,
#  'kivlanzenajukanpermohonanizinberobatdenganterbatuk': 863,
#  'batuk': 864,
#  'jikaasingingelarperundinganpelucutansenjatanukliriniyangdimintakoreautara': 865,
#  'livestreamingtvonlineindosiarpersijajakartavsbaliuniteddiliga12019aksesdisini': 866,
#  '4faktadibalikperhelatanbalkonjazzfestival2019': 867,
#  'lagunyadiviralkandutasheilaon7beginitanggapanlangitsore': 868,
#  '8pasanganzodiakyanghubungannyabertahanlamavirgodancapricornterciptasatusamalain': 869,
#  'cabulibocahenamtahunpedagangsusukelilingdibekasidiringkus': 870,
#  'taufikhidayatungkappesanbjhabibieketimpialathomas1998': 871,
#  'iphone11prodenganwarnaemassepipembeli': 872,
#  'warnarambutlagihitsdiinstagramcobayuk': 873,
#  'malaysiaberencanatidakpenjarakanpenggunanarkoba': 874,
#  'bersiaplawanbarcelonavalenciajustrupecatpelatihmarcelino': 875,
#  'imporricapaiusd142miliarturun15': 876,
#  'dishubdkiperluasanganjilgenapharipertamaperbaikikualitasudara': 877,
#  'tayangmalaminikamis19september2019aksibrucewilisdifilmviceditranstvpukul2300wib': 878,
#  'mantandirutpetraljaditersangkakorupsi': 879,
#  '5pilihanolahragasaathamilmudajalankakihinggapilates': 880,
#  '41kaderperindosumutlolosparlemensekjendppingatkanjangankorupsi': 881,
#  'dprusuldewanpengawaskpktakdipilihpemerintah': 882,
#  'pgiprihatinupayapelemahankpkiniaspirasinya': 883,
#  'wanitadengantubuhberisiterbuktibikinprialebihbahagia': 884,
#  'gyuriekskaradiam': 885,
#  'diampacaribrondongtajirintipfoto': 886,
#  'fotokencanmereka': 887,
#  'kepadapengusahajokowiingatkanketidakpastianekonomiglobal': 888,
#  'sebabtinggimejaloketjanganlebihdari1meter': 889,
#  'beredarvideopolisiteriakitnidimespatitnialinipenjelasanpolri': 890,
#  'ihsgdibukamenguattipiske6244': 891,
#  '10potretliburandiansastrobersamasuamidan2anaknya': 892,
#  'pangkastengkulaktbbmpertaminarewuluinisiasiprogramjapangmas': 893,
#  'menolakrevisiuukpkkatakapitraamperaitumakar': 894,
#  'crowngroupraihduapenghargaanbergengsidiaustralia': 895,
#  'caripemainesportsberbakatwatonggelarmlbbcompetition': 896,
#  'adachrisyedigoogledoodlehariini': 897,
#  'ekspengamencantikdisurabayainijadiwisudawanterbaikdiunairipk': 898,
#  'nya394': 899,
#  'queendomtanggapikabarsoalpesertabayarsendirisemuabiayapenampilan': 900,
#  'savethechildrenpemerintahabaikananakkorbankabutasap': 901,
#  '9pabriktekstiltutupmenperintakadarevitalisasipermesinan': 902,
#  'megawatiterekamtolaksalamisuryapalohisyaratkanpecahkongsi': 903,
#  'garamimpiburukperempuaninitelancincinpertunangannya': 904,
#  'tyasmirasihkompakanjalaniprogramdietbarengsuamitanpaolahraga': 905,
#  'melihatlebihdekatlianglahatuntukbj¬†habibie': 906,
#  'responsrahmaddarmawansaatdikabarkanakantanganitimnasindonesia': 907,
#  'dorongpenggunaankendaraanlistrikpermenhubdipercepat': 908,
#  'akanhadirdiindonesiavivov17prorilisdiindia20september': 909,
#  'eramobillistrikpenggunaanpelumasbisaturun50persen': 910,
#  'peluangkorupsidalamruupertanahan': 911,
#  'barbiekumalasaribakalkeamerikabarengboywilliambeginiceritanya': 912,
#  'bukuubocahgairahkanminatbacarumahbelajarjuara': 913,
#  'menkominfodorongpemanfaatankecerdasanbuatanuntuklayananpemerintahan': 914,
#  'pejetskiindonesiajuaraip1aquacrossdiamerika': 915,
#  'duagolrealmadridkegawangpsgdianulirvarbeginipenjelasannya': 916,
#  'genjotpajakdaripariwisatadisparbuddkigandengtraveloka': 917,
#  'lapindotakbayarutangrp17tkemenkeulayangkantagihanlagi': 918,
#  'banyaktempathiburanmalamditutuppajakdkitakcapaitarget': 919,
#  'ronaldoempatgolportugallumatlithuania5': 920,
#  'eksporindustrikerajinancapai870jutadolaras': 921,
#  'lucintalunajatuhterguling': 922,
#  'gulingdigurunsaharalalukegugurandokterterkejutlihatinidiusg': 923,
#  'resmidiluncurkaninigebrakanbarudifestivalfilmindonesia2019': 924,
#  'fahrihamzahusuljokowisegeralantikfirlicsinialasannya': 925,
#  'korselsebutsaudimintabantuanperkuatpertahananudara': 926,
#  'pembangunanpengolahansampahsunterdimulainovember2019': 927,
#  'dipukulidebtcolectorlaporpolisisudahsetahunlebihmasihnggakjelas': 928,
#  '5halmenarikbalkonjazzfestival2019pasarbalkonhinggaditutupyurayunita': 929,
#  'inggrisizinkanmahasiswaasingtinggalduatahunpascalulus': 930,
#  'ruukuhpditundaketuadprberharapbisaturunkantensipolitik': 931,
#  'lelangproyekjakartainternationalstadiumdiprotesapakatakementerianpupr': 932,
#  'bebbyfeymintarumahdanmobilmewahsebagaisyaratdamaidengansangyoutuberterkenal': 933,
#  'filmloveforsale2luncurkantrailerperdanadengancarauniksepertiapa': 934,
#  'tigapejabatpemkotinginmajupilkadatangsel2020apakataairin': 935,
#  'yusrilnilaidewanpengawasbisamelekatdengankpk': 936,
#  'pelatihtimnasindonesiasebutduapemainthailandinipunyakualitaspembeda': 937,
#  'koreadramaawards2019kimjiwondanyooinnasainganinidaftarlengkapnominasinya': 938,
#  '19tekukiranfakhrihusainisemogajadipelipurlara': 939,
#  'nagitaslavinaogahmenginapdihotelmewahmilikmamarietaraffiahmadungkapalasannya': 940,
#  'cukainaikpicurokokilegalpemerintahintensifkanpenindakan': 941,
#  'novantokembalikanuangpenggantikorupsiiniperinciannya': 942,
#  'sinopsissinetroncintasuciepisode318': 943,
#  '319tayangkamis18april2019': 944,
#  'jadisorotaninilahbedareaksikipertimnasindonesiadanwingerthailand': 945,
#  'kasuskorupsigubernurkeprikpkperiksakadispupr': 946,
#  'kembalinaikutangluarnegeriindonesiatembusrp5534triliun': 947,
#  'polisipersilahkanveronicakomantempuhupayahukumsoalstatustersangka': 948,
#  'kivlanzenakanajukannotakeberatanuntuktolakdakwaanjaksa': 949,
#  'viraljeritankorbantabrakanmautdisumaterabikinmerinding': 950,
#  'prediksibosjaguarlandroversoalmobillistrikyangjaminbikinciut': 951,
#  'lolosdarihukumanmatikekayaanbandarnarkobainikalahkansandiagauno': 952,
#  'ibukotabarudikritikridwankamilterlaluluasinikomentargubernurkaltim': 953,
#  'kontaktembakdiilagapapuaseorangbalitatewas': 954,
#  'kisahkorbanpenculikanisisalamikekerasanseksualhinggadijual20kali': 955,
#  'aplikasibukalapakmenghilangdarigoogleplaystoreadaapa': 956,
#  'garudaluncurkanaplikasilayananpengirimanlogistik': 957,
#  'surprisehargatiketkejepanglebihmurahdaripadajakarta': 958,
#  'pekanbaru': 959,
#  '8tipsagarbagasiamandantidakdiboboldibandara': 960,
#  'bocahdibekasidisebuttewaskarenabullykpadimbaukeluargamelapor': 961,
#  'hijaberssudahtepatkahcaramerawatrambutmucaritahulewatkuisiniyuk': 962,
#  'investasikorseldiyakiniperkuatstrukturmanufakturindonesia': 963,
#  'kenali10tahapanpendaftarancpns2019dandokumenyangdiperlukangurudannakespalingdicari': 964,
#  'tipsbeliemasdigitalbisadicicillaludijuallagi': 965,
#  'dprakanpilih5pimpinankpkperiode2019': 966,
#  '2023malamini': 967,
#  '5fiturmenariktoyotacalyayangwajibdiketahui': 968,
#  '35orangtewasdipestapernikahanakibatseranganpasukanafghanistan': 969,
#  'tukanggalondanairminumnyalonpilkadatangsel': 970,
#  'berbagaikeluhanpengendaradiharipertamapenerapanperluasanganjilgenap': 971,
#  'ceritalucujinbtstaksengajapapasandengansugasaatbersepedakekantor': 972,
#  'polri': 973,
#  'tnigelarapelpengamananjelangunjukrasadidpr': 974,
#  'anakbjhabibienyatakanayahnyatakakandibawakejerman': 975,
#  'terpaparkabutasapkarhutlajambelajarsmadisumseldimundurkan': 976,
#  'postingfototeasercomebackleedonghaesuperjuniormalahbuatfansngakakgara': 977,
#  'rasioelektrifikasibisa100': 978,
#  'denganenergiterbarukan': 979,
#  'sebelumdisiksasuamitigasetiagararayakanulangtahunpernikahan': 980,
#  'daftar8unggulantersingkirdibabakpertamachinaopen2019adawakilindonesia': 981,
#  'mintapolisitenanghadapidemomahasiswaprabowocontohkanprancis': 982,
#  '11orangtewasakibatbanjirbandangdiindia28000orangdievakuasi': 983,
#  'miliarderjepangsebutbrexitmustahildiwujudkan': 984,
#  'pasokanavturkebandarakertajatijauhdibawahbandarasoekarno': 985,
#  'lanyallabikingegerusaiterpilihjadiketuadpdinialasannya': 986,
#  'perhitungansuarabelumselesaiadlyfairuzdipastikanmenujugedungdprri': 987,
#  'sempatalamipendarahanirishbellalebihberhati': 988,
#  'bppdbaliajukanrevisipasalrkuhpyangdinilaiganggupariwisata': 989,
#  'kpkgeledahkantordinaspudanpendidikankepri': 990,
#  'massaaksigejayanmemanggilmulaiberkumpuldipertigaancolombo': 991,
#  'penyebabaplikasitemposempathilangdariplaystore': 992,
#  'jeongyeontwicekagetsaattahuchaeryeongitzyternyatatetangganya': 993,
#  'selfiedenganhabibie': 994,
#  'santanhinggadaunpandaninibahanpelengkapjajanantradisional': 995,
#  'teganyapabrikminyakgorengdimedanpecatkaryawanjelanglebaran': 996,
#  'catatanimpresifcristianoronaldokegawangatleticobakalberlanjut': 997,
#  'gubernurjabarperkuatkoordinasidengankabupatendankotadikopdar': 998,
#  'gwpp': 999,
#  '6perampokbersebotembakwargahinggatewasdisumsel': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 7760

# %%
lengths = []
for sentence in X_train_title:
    lengths.append(len(sentence))

print('Longest sentence\t:', max(lengths))
print('Shortest sentence\t:', min(lengths))
print('Average length\t\t:', np.mean(lengths))
# Out:
# Longest sentence	: 10
# Shortest sentence	: 1
# Average length		: 1.1593613933236575

# %%
X_train_title = sequence.pad_sequences(X_train_title, maxlen=19)
X_test_title = sequence.pad_sequences(X_test_title, maxlen=19)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.array([0, 1]), y=y_train.values)
class_weights
# Out:
# array([0.80868545, 1.30988593])

# %%
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: np.float64(0.8086854460093896), 1: np.float64(1.3098859315589353)}

# %%
print(X_train_title.shape)
print(X_test_title.shape)
# Out:
# (6890, 19)
# (1723, 19)

# %%
tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=32)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm = Dense(3, activation='sigmoid')(lstm)

lstm_model = Model(inputs=lstm_input, outputs=lstm)

# %%
dense_input = Input(shape=(10,))
dense = Dropout(rate=0.5) (dense_input)
dense = Dense(3, activation='sigmoid') (dense)
dense_model = Model(inputs=dense_input, outputs=dense)

# %%
print(X_train_punc.shape)
print(X_test_punc.shape)
# Out:
# (6890, 10)
# (1723, 10)

# %%
concat = concatenate([lstm_model.output, dense_model.output])
concat = Dense(6, activation='sigmoid')(concat)
concat = Dense(1, activation='sigmoid')(concat)
model = Model(inputs=[lstm_model.input, dense_model.input], outputs=concat)

# %%
plot_model(model)

# %%
model.compile(loss='binary_crossentropy',
optimizer='adam',
metrics=['acc'])

# %%
history = model.fit(
    [X_train_title, X_train_punc],
    y_train,
    epochs=4,
    batch_size=64, class_weight=class_weight_dict,
    validation_data=([X_test_title, X_test_punc], y_test))
# Out:
# Epoch 1/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.5141 - loss: 0.6947 - val_acc: 0.3981 - val_loss: 0.7019
# Epoch 2/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - acc: 0.4920 - loss: 0.6934 - val_acc: 0.3987 - val_loss: 0.7019
# Epoch 3/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - acc: 0.4880 - loss: 0.6931 - val_acc: 0.3987 - val_loss: 0.7022
# Epoch 4/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - acc: 0.5093 - loss: 0.6900 - val_acc: 0.3987 - val_loss: 0.7020

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])
